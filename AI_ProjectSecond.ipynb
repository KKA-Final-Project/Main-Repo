# %%
pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 15.5 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests
import folium
import networkx as nx
import random
import math

df = pd.read_csv('D:/ITS/Study/Semester 3/A.I Concepts/Final Project/archive/open_pubs.csv')

#Cleaning
df['latitude'] = pd.to_numeric(df['latitude'], errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')
df = df.dropna(subset=['latitude', 'longitude'])
df = df.drop_duplicates(subset=['name'], keep='last')

cities_amt = int(input("How many cities?"))

# Choose a city to limit the dataset size
chosen_city = "City of London"
df_chosen_city = df[df['local_authority'] == chosen_city].head(cities_amt)  

# OSRM function to get the shortest route and distance between two locations
def get_osrm_route(start_coords, end_coords):
    url = f"http://router.project-osrm.org/route/v1/driving/{start_coords[1]},{start_coords[0]};{end_coords[1]},{end_coords[0]}?overview=full&geometries=geojson"
    response = requests.get(url)
    
    if response.status_code == 200:
        route_data = response.json()
        distance_meters = route_data['routes'][0]['distance']  # Distance in meters
        route_coords = route_data['routes'][0]['geometry']['coordinates']
        return route_coords, distance_meters
    else:
        return None, None

# Initialize a Folium map
m = folium.Map(location=[df_chosen_city['latitude'].mean(), df_chosen_city['longitude'].mean()], zoom_start=13)

# Get pub locations and names
pub_locations = list(zip(df_chosen_city['latitude'], df_chosen_city['longitude']))  # Condense coordinates into tuples
pub_names = df_chosen_city['name'].tolist()  # List of pub names

# Add pub markers to the map
for index, row in df_chosen_city.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=f"{row['name']}<br>{row['address']}<br>{row['postcode']}",).add_to(m)

# Initialize an empty graph using networkx
G = nx.Graph()

# Add nodes (pubs) to the graph
for i, pub_name in enumerate(pub_names):
    G.add_node(pub_name, pos=pub_locations[i])

# Add edges (routes between pubs) and calculate distances
total_distance = 0

for i in range(len(pub_locations) - 1):
    for j in range(i + 1, len(pub_locations)):  # Connect all pubs (fully connected graph)
        start_coords = pub_locations[i]
        end_coords = pub_locations[j]
        
        # Get route coordinates and distance from OSRM
        route, distance_meters = get_osrm_route(start_coords, end_coords)
        
        if route:
            # Convert distance to kilometers
            distance_km = distance_meters / 1000
            total_distance += distance_km
            
            # Convert route coordinates to lat-lng for folium display
            route_latlong = [(coord[1], coord[0]) for coord in route]
            
            # Add route as polyline to the map
            folium.PolyLine(locations=route_latlong, color='blue', weight=2.5, opacity=0.8).add_to(m)
            
            # Add an edge to the graph with distance as the weight
            G.add_edge(pub_names[i], pub_names[j], weight=distance_km)
            


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1954174c080220243dc4db1cacc601d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1954174c080220243dc4db1cacc601d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1954174c080220243dc4db1cacc601d = L.map(
#                 &quot;map_a1954174c080220243dc4db1cacc601d&quot;,
#                 {
#                     center: [51.51492244999999, -0.08735865000000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da1ad4d2c66c330c2eedaeadefb14180 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_da1ad4d2c66c330c2eedaeadefb14180.addTo(map_a1954174c080220243dc4db1cacc601d);
#
#
#             var marker_e69dc3e6c406354eed0d63ed83b078b5 = L.marker(
#                 [51.51242, -0.075158],
#                 {}
#             ).addTo(map_a1954174c080220243dc4db1cacc601d);
#
#
#         var popup_e2c23c875fa550da4575db3ba8f34223 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18660a602171cd016e411b9ff9d1a0d8 = $(`&lt;div id=&quot;html_18660a602171cd016e411b9ff9d1a0d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey&lt;br&gt;St Clare House, 30-33 Minories, London&lt;br&gt;EC3N 1DD&lt;/div&gt;`)[0];
#                 popup_e2c23c875fa550da4575db3ba8f34223.setContent(html_18660a602171cd016e411b9ff9d1a0d8);
#
#
#
#         marker_e69dc3e6c406354eed0d63ed83b078b5.bindPopup(popup_e2c23c875fa550da4575db3ba8f34223)
#         ;
#
#
#
#
#             var marker_3f886fe4b698d80553a2371992e8a207 = L.marker(
#                 [51.510332, -0.081083],
#                 {}
#             ).addTo(map_a1954174c080220243dc4db1cacc601d);
#
#
#         var popup_4a16f6ccde85f6001bb0096efe8a165c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3e4038fec5018bf6b6ffd51fae14318 = $(`&lt;div id=&quot;html_a3e4038fec5018bf6b6ffd51fae14318&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agenda&lt;br&gt;3 Minster Court, London&lt;br&gt;EC3R 7DD&lt;/div&gt;`)[0];
#                 popup_4a16f6ccde85f6001bb0096efe8a165c.setContent(html_a3e4038fec5018bf6b6ffd51fae14318);
#
#
#
#         marker_3f886fe4b698d80553a2371992e8a207.bindPopup(popup_4a16f6ccde85f6001bb0096efe8a165c)
#         ;
#
#
#
#
#             var marker_5a8abb00d3c30e290811b9548056af12 = L.marker(
#                 [51.519437, -0.089608],
#                 {}
#             ).addTo(map_a1954174c080220243dc4db1cacc601d);
#
#
#         var popup_b34388d08ac718007d5e5fa2d4f25d66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52c649589ac9c284edb97bc09628455b = $(`&lt;div id=&quot;html_52c649589ac9c284edb97bc09628455b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amber Bar&lt;br&gt;City Point, 1 Ropemaker Street, London&lt;br&gt;EC2Y 9AW&lt;/div&gt;`)[0];
#                 popup_b34388d08ac718007d5e5fa2d4f25d66.setContent(html_52c649589ac9c284edb97bc09628455b);
#
#
#
#         marker_5a8abb00d3c30e290811b9548056af12.bindPopup(popup_b34388d08ac718007d5e5fa2d4f25d66)
#         ;
#
#
#
#
#             var marker_dd02d5e7b779c649bd99f8b32e08ed9b = L.marker(
#                 [51.517782, -0.078622],
#                 {}
#             ).addTo(map_a1954174c080220243dc4db1cacc601d);
#
#
#         var popup_7cf75138b85015c7aa373c676f493e09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c9f4eaca7e005238e332aef74253d4a = $(`&lt;div id=&quot;html_8c9f4eaca7e005238e332aef74253d4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Astronomer&lt;br&gt;125-129 Middlesex Street, London&lt;br&gt;E1 7JF&lt;/div&gt;`)[0];
#                 popup_7cf75138b85015c7aa373c676f493e09.setContent(html_8c9f4eaca7e005238e332aef74253d4a);
#
#
#
#         marker_dd02d5e7b779c649bd99f8b32e08ed9b.bindPopup(popup_7cf75138b85015c7aa373c676f493e09)
#         ;
#
#
#
#
#             var marker_4b18427e767acc0ef28b2784cf693625 = L.marker(
#                 [51.515695, -0.084028],
#                 {}
#             ).addTo(map_a1954174c080220243dc4db1cacc601d);
#
#
#         var popup_a0aa4486e3cfe0c2f5bc68f8b1d9e18d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19bf1d9338056f4035eb3871a490915b = $(`&lt;div id=&quot;html_19bf1d9338056f4035eb3871a490915b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Babble City&lt;br&gt;45 Old Broad Street, London&lt;br&gt;EC2N 1HT&lt;/div&gt;`)[0];
#                 popup_a0aa4486e3cfe0c2f5bc68f8b1d9e18d.setContent(html_19bf1d9338056f4035eb3871a490915b);
#
#
#
#         marker_4b18427e

# %%
import time

# %%
def calculate_route_distance(route, graph):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += graph[route[i]][route[i + 1]]['weight']
    return total_distance

def simulated_annealing(graph, initial_route):
    current_route = initial_route.copy()
    current_distance = calculate_route_distance(current_route, graph)
    best_route = current_route
    best_distance = current_distance

    temperature = 1000.0
    cooling_rate = 0.9999
    while temperature > 1:
        new_route = current_route.copy()
        i, j = random.sample(range(len(new_route)), 2)
        new_route[i], new_route[j] = new_route[j], new_route[i]
        
        new_distance = calculate_route_distance(new_route, graph)
        if new_distance < current_distance or random.random() < math.exp((current_distance - new_distance) / temperature):
            current_route = new_route
            current_distance = new_distance
            
            if current_distance < best_distance:
                best_route = current_route
                best_distance = current_distance

        temperature *= cooling_rate

    return best_route, best_distance

start_time = time.time()


initial_route = pub_names

optimized_route, optimized_distance = simulated_annealing(G, initial_route)

optimized_route.append(optimized_route[0]) 

end_time = time.time()
elapsed_time = end_time - start_time

print("Optimized Route:", " -> ".join(optimized_route))
print(f"Optimized Distance: {optimized_distance:.2f} km")
print(f"Simulated Annealing Time: {elapsed_time:.4f} seconds")

m_optimized = folium.Map(location=[df_chosen_city['latitude'].mean(), df_chosen_city['longitude'].mean()], zoom_start=13)

for index, row in df_chosen_city.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=f"{row['name']}<br>{row['address']}<br>{row['postcode']}").add_to(m_optimized)

for i in range(len(optimized_route) - 1):
    start_pub = optimized_route[i]
    end_pub = optimized_route[i + 1]
    
    start_coords = G.nodes[start_pub]['pos']
    end_coords = G.nodes[end_pub]['pos']
    
    route, _ = get_osrm_route(start_coords, end_coords)
    if route:
        route_latlong = [(coord[1], coord[0]) for coord in route]
        
        folium.PolyLine(locations=route_latlong, color='red', weight=2.5, opacity=0.8).add_to(m_optimized)

# Display the optimized map
m_optimized
# Out:
# Optimized Route: Babble City -> Balls Brothers Austin Friars -> Astronomer -> Balls Brothers, Mark Lane -> Brokers Wine Bar -> Bedales Wine Bar -> Balls Brothers Wine Bar -> Abbey -> Balls Brothers Ltd -> Bottlescrue -> City Boot -> Circle Bar, Level 0 -> Bangers -> Amber Bar -> Bishops Finger -> Balls Brothers Shoe Lane -> City Flogger -> Balls Brothers @ Minster Court -> Agenda -> Cannick Tapps -> Babble City
# Optimized Distance: 19.28 km
# Simulated Annealing Time: 1.1159 seconds
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e98e175cba60cfe73ea22f950b0abd7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e98e175cba60cfe73ea22f950b0abd7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e98e175cba60cfe73ea22f950b0abd7b = L.map(
#                 &quot;map_e98e175cba60cfe73ea22f950b0abd7b&quot;,
#                 {
#                     center: [51.51492244999999, -0.08735865000000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb9d3c7a58c811c9c5d0d642dfda1f03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb9d3c7a58c811c9c5d0d642dfda1f03.addTo(map_e98e175cba60cfe73ea22f950b0abd7b);
#
#
#             var marker_4f8a29c81d5e3c55a035f93452d790ea = L.marker(
#                 [51.51242, -0.075158],
#                 {}
#             ).addTo(map_e98e175cba60cfe73ea22f950b0abd7b);
#
#
#         var popup_0fef4cb28eed3349e1a4b5f12e41f074 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdadd21607555cf02da2e88354768294 = $(`&lt;div id=&quot;html_fdadd21607555cf02da2e88354768294&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey&lt;br&gt;St Clare House, 30-33 Minories, London&lt;br&gt;EC3N 1DD&lt;/div&gt;`)[0];
#                 popup_0fef4cb28eed3349e1a4b5f12e41f074.setContent(html_fdadd21607555cf02da2e88354768294);
#
#
#
#         marker_4f8a29c81d5e3c55a035f93452d790ea.bindPopup(popup_0fef4cb28eed3349e1a4b5f12e41f074)
#         ;
#
#
#
#
#             var marker_77f465c0c8af19e0bd0b8cb8d41fc825 = L.marker(
#                 [51.510332, -0.081083],
#                 {}
#             ).addTo(map_e98e175cba60cfe73ea22f950b0abd7b);
#
#
#         var popup_a04b2dda3b94096f5f7fb3f7f3715330 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a9a446927756da0f6aa5c18b871151e = $(`&lt;div id=&quot;html_3a9a446927756da0f6aa5c18b871151e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agenda&lt;br&gt;3 Minster Court, London&lt;br&gt;EC3R 7DD&lt;/div&gt;`)[0];
#                 popup_a04b2dda3b94096f5f7fb3f7f3715330.setContent(html_3a9a446927756da0f6aa5c18b871151e);
#
#
#
#         marker_77f465c0c8af19e0bd0b8cb8d41fc825.bindPopup(popup_a04b2dda3b94096f5f7fb3f7f3715330)
#         ;
#
#
#
#
#             var marker_b071d5f54e66d7d959347afe1d4ef4d7 = L.marker(
#                 [51.519437, -0.089608],
#                 {}
#             ).addTo(map_e98e175cba60cfe73ea22f950b0abd7b);
#
#
#         var popup_70df7fd36fb5c4115ecfbd828d6e1f20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59a9ed7af7bd60b0a584ead817cb3506 = $(`&lt;div id=&quot;html_59a9ed7af7bd60b0a584ead817cb3506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amber Bar&lt;br&gt;City Point, 1 Ropemaker Street, London&lt;br&gt;EC2Y 9AW&lt;/div&gt;`)[0];
#                 popup_70df7fd36fb5c4115ecfbd828d6e1f20.setContent(html_59a9ed7af7bd60b0a584ead817cb3506);
#
#
#
#         marker_b071d5f54e66d7d959347afe1d4ef4d7.bindPopup(popup_70df7fd36fb5c4115ecfbd828d6e1f20)
#         ;
#
#
#
#
#             var marker_f8212ac9af7bf51b99bbc95750d585ff = L.marker(
#                 [51.517782, -0.078622],
#                 {}
#             ).addTo(map_e98e175cba60cfe73ea22f950b0abd7b);
#
#
#         var popup_495e895c2d3baf22e66917890588efe2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c359fbd17d8ca4249631edffef7745a = $(`&lt;div id=&quot;html_0c359fbd17d8ca4249631edffef7745a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Astronomer&lt;br&gt;125-129 Middlesex Street, London&lt;br&gt;E1 7JF&lt;/div&gt;`)[0];
#                 popup_495e895c2d3baf22e66917890588efe2.setContent(html_0c359fbd17d8ca4249631edffef7745a);
#
#
#
#         marker_f8212ac9af7bf51b99bbc95750d585ff.bindPopup(popup_495e895c2d3baf22e66917890588efe2)
#         ;
#
#
#
#
#             var marker_da6a59c875e5b396123c0a92cb4a5e0b = L.marker(
#                 [51.515695, -0.084028],
#                 {}
#             ).addTo(map_e98e175cba60cfe73ea22f950b0abd7b);
#
#
#         var popup_b108a173d407a3f66a56fb071b9b086c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cece7b17abb826759030b44fbcc40b51 = $(`&lt;div id=&quot;html_cece7b17abb826759030b44fbcc40b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Babble City&lt;br&gt;45 Old Broad Street, London&lt;br&gt;EC2N 1HT&lt;/div&gt;`)[0];
#                 popup_b108a173d407a3f66a56fb071b9b086c.setContent(html_cece7b17abb826759030b44fbcc40b51);
#
#
#
#         marker_da6a59c8

# %%
##genetic algorithm

# Fitness function to calculate the total distance of a route
def calculate_route_distance(route, graph):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += graph[route[i]][route[i + 1]]['weight']
    total_distance += graph[route[-1]][route[0]]['weight']  # Complete the cycle
    return total_distance

# Create an initial population of random routes
def create_initial_population(population_size, pub_names):
    population = []
    for _ in range(population_size):
        route = pub_names[:]
        random.shuffle(route)
        population.append(route)
    return population

# Select the best individuals for mating (tournament selection)
def selection(population, graph, tournament_size=5):
    selected = []
    for _ in range(tournament_size):
        individual = random.choice(population)
        selected.append(individual)
    selected.sort(key=lambda x: calculate_route_distance(x, graph))
    return selected[0]  # Return the best individual in the tournament

# Crossover function to create a child route
def crossover(parent1, parent2):
    size = len(parent1)
    start, end = sorted(random.sample(range(size), 2))
    child = [None] * size
    # Inherit a subset from parent1
    child[start:end] = parent1[start:end]
    # Fill remaining positions with genes from parent2 in order
    ptr = 0
    for gene in parent2:
        if gene not in child:
            while child[ptr] is not None:
                ptr += 1
            child[ptr] = gene
    return child

# Mutation function to introduce some variations
def mutate(route, mutation_rate=0.01):
    for i in range(len(route)):
        if random.random() < mutation_rate:
            j = random.randint(0, len(route) - 1)
            route[i], route[j] = route[j], route[i]  # Swap two pubs
    return route

# Main Genetic Algorithm function
def genetic_algorithm(graph, pub_names, population_size=100, generations=500, mutation_rate=0.01):
    population = create_initial_population(population_size, pub_names)
    best_route = min(population, key=lambda x: calculate_route_distance(x, graph))
    best_distance = calculate_route_distance(best_route, graph)

    for generation in range(generations):
        new_population = []

        # Create new population through selection, crossover, and mutation
        for _ in range(population_size):
            parent1 = selection(population, graph)
            parent2 = selection(population, graph)
            child = crossover(parent1, parent2)
            child = mutate(child, mutation_rate)
            new_population.append(child)

        # Update population and track the best route
        population = new_population
        current_best_route = min(population, key=lambda x: calculate_route_distance(x, graph))
        current_best_distance = calculate_route_distance(current_best_route, graph)

        if current_best_distance < best_distance:
            best_route = current_best_route
            best_distance = current_best_distance

        # Optionally, print progress every 50 generations
        if generation % 50 == 0:
            print(f"Generation {generation}: Best Distance = {best_distance:.2f} km")

    return best_route, best_distance

# Running the Genetic Algorithm
start_time = time.time()

# Initial route setup and running the algorithm
optimized_route, optimized_distance = genetic_algorithm(G, pub_names, population_size=100, generations=500, mutation_rate=0.01)

end_time = time.time()
elapsed_time = end_time - start_time


print("Optimized Route:", " -> ".join(optimized_route))
print(f"Optimized Distance: {optimized_distance:.2f} km")
print(f"Genetic Algorithm Time: {elapsed_time:.4f} seconds")

# Save results to a text file
with open("genetic_algorithm_results.txt", "w") as file:
    file.write("Optimized Route:\n" + " -> ".join(optimized_route) + "\n")
    file.write(f"Optimized Distance: {optimized_distance:.2f} km\n")
    file.write(f"Genetic Algorithm Time: {elapsed_time:.4f} seconds\n")

print("Results saved to genetic_algorithm_results.txt")

# Visualizing the optimized route on a map
m_optimized_genetic = folium.Map(location=[df_chosen_city['latitude'].mean(), df_chosen_city['longitude'].mean()], zoom_start=13)

# Add markers and optimized route to the map
for index, row in df_chosen_city.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=f"{row['name']}<br>{row['address']}<br>{row['postcode']}").add_to(m_optimized_genetic)

# Plot optimized route on the map
optimized_route.append(optimized_route[0])  # Complete the cycle
for i in range(len(optimized_route) - 1):
    start_pub = optimized_route[i]
    end_pub = optimized_route[i + 1]
    
    start_coords = G.nodes[start_pub]['pos']
    end_coords = G.nodes[end_pub]['pos']
    
    route, _ = get_osrm_route(start_coords, end_coords)
    if route:
        route_latlong = [(coord[1], coord[0]) for coord in route]
        
        folium.PolyLine(locations=route_latlong, color='green', weight=2.5, opacity=0.8).add_to(m_optimized_genetic)

# Display the optimized map
m_optimized_genetic
# Out:
# Generation 0: Best Distance = 24.50 km
# Generation 50: Best Distance = 17.00 km
# Generation 100: Best Distance = 17.00 km
# Generation 150: Best Distance = 17.00 km
# Generation 200: Best Distance = 17.00 km
# Generation 250: Best Distance = 17.00 km
# Generation 300: Best Distance = 17.00 km
# Generation 350: Best Distance = 17.00 km
# Generation 400: Best Distance = 17.00 km
# Generation 450: Best Distance = 16.68 km
# Optimized Route: Abbey -> Balls Brothers @ Minster Court -> City Flogger -> Balls Brothers, Mark Lane -> Agenda -> Bedales Wine Bar -> Brokers Wine Bar -> Balls Brothers Wine Bar -> Circle Bar, Level 0 -> Amber Bar -> City Boot -> Balls Brothers Ltd -> Bottlescrue -> Cannick Tapps -> Balls Brothers Shoe Lane -> Bishops Finger -> Bangers -> Babble City -> Balls Brothers Austin Friars -> Astronomer
# Optimized Distance: 16.68 km
# Genetic Algorithm Time: 7.8121 seconds
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_481edbbee4c93366db97d357564af26a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_481edbbee4c93366db97d357564af26a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_481edbbee4c93366db97d357564af26a = L.map(
#                 &quot;map_481edbbee4c93366db97d357564af26a&quot;,
#                 {
#                     center: [51.51492244999999, -0.08735865000000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_408de780a2e5213119dafb87dacae482 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_408de780a2e5213119dafb87dacae482.addTo(map_481edbbee4c93366db97d357564af26a);
#
#
#             var marker_a8aa36a97f89ba6785e6dc7ea93138f4 = L.marker(
#                 [51.51242, -0.075158],
#                 {}
#             ).addTo(map_481edbbee4c93366db97d357564af26a);
#
#
#         var popup_3b2ce85128c46b3a9244fdd790417a12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55b195db41eeb4d672cf7587e34cd7ac = $(`&lt;div id=&quot;html_55b195db41eeb4d672cf7587e34cd7ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey&lt;br&gt;St Clare House, 30-33 Minories, London&lt;br&gt;EC3N 1DD&lt;/div&gt;`)[0];
#                 popup_3b2ce85128c46b3a9244fdd790417a12.setContent(html_55b195db41eeb4d672cf7587e34cd7ac);
#
#
#
#         marker_a8aa36a97f89ba6785e6dc7ea93138f4.bindPopup(popup_3b2ce85128c46b3a9244fdd790417a12)
#         ;
#
#
#
#
#             var marker_5d85b5081feb23e7e2705073fac5ddf5 = L.marker(
#                 [51.510332, -0.081083],
#                 {}
#             ).addTo(map_481edbbee4c93366db97d357564af26a);
#
#
#         var popup_88a4c09e86d27c7e2e9f76681fcceb89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c7583406e1196e59a6bd6bd48ee54dab = $(`&lt;div id=&quot;html_c7583406e1196e59a6bd6bd48ee54dab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agenda&lt;br&gt;3 Minster Court, London&lt;br&gt;EC3R 7DD&lt;/div&gt;`)[0];
#                 popup_88a4c09e86d27c7e2e9f76681fcceb89.setContent(html_c7583406e1196e59a6bd6bd48ee54dab);
#
#
#
#         marker_5d85b5081feb23e7e2705073fac5ddf5.bindPopup(popup_88a4c09e86d27c7e2e9f76681fcceb89)
#         ;
#
#
#
#
#             var marker_d2c9ece63ddd1d2c027e72b0962f6934 = L.marker(
#                 [51.519437, -0.089608],
#                 {}
#             ).addTo(map_481edbbee4c93366db97d357564af26a);
#
#
#         var popup_bfb319f96dcc0926d3caf08739720014 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5587fbacb5bd2f0b64b1a630a44430a0 = $(`&lt;div id=&quot;html_5587fbacb5bd2f0b64b1a630a44430a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amber Bar&lt;br&gt;City Point, 1 Ropemaker Street, London&lt;br&gt;EC2Y 9AW&lt;/div&gt;`)[0];
#                 popup_bfb319f96dcc0926d3caf08739720014.setContent(html_5587fbacb5bd2f0b64b1a630a44430a0);
#
#
#
#         marker_d2c9ece63ddd1d2c027e72b0962f6934.bindPopup(popup_bfb319f96dcc0926d3caf08739720014)
#         ;
#
#
#
#
#             var marker_f4e0e0ca2eb36baf4e7fd862cc246278 = L.marker(
#                 [51.517782, -0.078622],
#                 {}
#             ).addTo(map_481edbbee4c93366db97d357564af26a);
#
#
#         var popup_06f5c3d0e2f6064ad13dfc4ce8bc3200 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97370f9b84997023550f097602beffac = $(`&lt;div id=&quot;html_97370f9b84997023550f097602beffac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Astronomer&lt;br&gt;125-129 Middlesex Street, London&lt;br&gt;E1 7JF&lt;/div&gt;`)[0];
#                 popup_06f5c3d0e2f6064ad13dfc4ce8bc3200.setContent(html_97370f9b84997023550f097602beffac);
#
#
#
#         marker_f4e0e0ca2eb36baf4e7fd862cc246278.bindPopup(popup_06f5c3d0e2f6064ad13dfc4ce8bc3200)
#         ;
#
#
#
#
#             var marker_04afcd45ad8f88bc5db129bf5f94593c = L.marker(
#                 [51.515695, -0.084028],
#                 {}
#             ).addTo(map_481edbbee4c93366db97d357564af26a);
#
#
#         var popup_f60e3c9c34c45e6b857995c91f460659 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_108aea414dceb16f87ab842e5a4534ee = $(`&lt;div id=&quot;html_108aea414dceb16f87ab842e5a4534ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Babble City&lt;br&gt;45 Old Broad Street, London&lt;br&gt;EC2N 1HT&lt;/div&gt;`)[0];
#                 popup_f60e3c9c34c45e6b857995c91f460659.setContent(html_108aea414dceb16f87ab842e5a4534ee);
#
#
#
#         marker_04afcd45

# %%
filename = f"genetic_alg_{optimized_distance:.2f}km_{cities_amt}cities.html"
m_optimized_genetic.save(filename)
